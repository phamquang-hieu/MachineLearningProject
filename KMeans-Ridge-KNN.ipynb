# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.datasets import load_boston
from sklearn.metrics import r2_score, mean_squared_error
import sys

# %%
def Kmeans_Ridge_KNN(X, y, train_index, test_index, p1, p2, alpha=0.01, n_clusters=2):
    X_train, X_test = X.iloc[train_index, :], X.iloc[test_index, :]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    n_clusters = n_clusters

    kmeans = KMeans(n_clusters=n_clusters, init="k-means++", max_iter=500, tol=1e-4)
    kmeans.fit(X_train)

    models = []
    y_train_pred = np.array([])
    y_train_true = np.array([])
    labels = kmeans.labels_
    idtrain = np.array([])
    for c in range(n_clusters):
        r = Ridge(alpha=alpha, normalize=False, solver="lsqr")
        r.fit(X_train[labels == c], y_train[labels == c])
        result = r.predict(X_train[labels == c])
        y_train_pred = np.append(y_train_pred, r.predict(X_train[labels == c]))
        y_train_true = np.append(y_train_true, y_train[labels == c])
        idtrain = np.append(idtrain, train_index[labels == c])
        models.append(r)

    knn = KNeighborsClassifier(n_neighbors=10, weights="distance")
    knn.fit(X_train, kmeans.labels_)

    y_test_pred = np.array([])
    y_test_true = np.array([])
    labels = knn.predict(X_test)
    idtest = np.array([])
    for c in range(n_clusters):
        y_test_pred = np.append(y_test_pred, models[c].predict(X_test[labels == c]))
        y_test_true = np.append(y_test_true, y_test[labels == c])
        idtest = np.append(idtest, test_index[labels == c])

    for i in range(len(idtrain)):
        y_train_pred[i] *= (
            1.00
            + p1 * df.loc[idtrain[i]]["CHAS"] / 100
            + p2 * df.loc[idtrain[i]]["RAD"] / 100
        )
        y_train_true[i] *= (
            1.00
            + p1 * df.loc[idtrain[i]]["CHAS"] / 100
            + p2 * df.loc[idtrain[i]]["RAD"] / 100
        )

    for i in range(len(idtest)):
        y_test_pred[i] *= (
            1.00
            + p1 * df.loc[idtest[i]]["CHAS"] / 100
            + p2 * df.loc[idtest[i]]["RAD"] / 100
        )
        y_test_true[i] *= (
            1.00
            + p1 * df.loc[idtest[i]]["CHAS"] / 100
            + p2 * df.loc[idtest[i]]["RAD"] / 100
        )

    r2_on_train = r2_score(y_train_pred, y_train_true)
    r2_on_test = r2_score(y_test_pred, y_test_true)
    return r2_on_train, r2_on_test

# %%
def kfold(p1, p2):
    scaler = MinMaxScaler()
    X = df.drop(columns=["MEDV", "CHAS", "RAD"])
    X["ONES"] = [1] * X.shape[0]
    print(X.columns)
    cols = X.columns
    X = scaler.fit_transform(X)
    X = pd.DataFrame(X, columns=cols)
    y = df["MEDV"] / (1.00 + df["CHAS"] * p1 / 100 + df["RAD"] * p2 / 100)
    kfold = KFold(n_splits=5, shuffle=True, random_state=1)
    r2_train = []
    r2_test = []
    for train_index, test_index in kfold.split(X):
        r2_on_train, r2_on_test = Kmeans_Ridge_KNN(
            X, y, train_index, test_index, p1, p2
        )
        r2_train.append(r2_on_train)
        r2_test.append(r2_on_test)
    print(np.mean(r2_train), np.mean(r2_test))
    return np.mean(r2_train), np.mean(r2_test)

# %%
df = pd.read_csv("processed_original.csv")

# %%
best_p1 = best_p2 = best_r2_train = best_r2_test = 0
prev_r2_train = prev_r2_test = 0
for i in range(0, 5):
    for j in range(0, 5):
        p1 = i * 1
        p2 = j * 1
        print("Processing hypothesis with p1 =", p1, "p2 = ", p2)
        r2_train, r2_test = kfold(p1, p2)
        prev_r2_train, prev_r2_test = r2_train, r2_test
        if best_r2_test < r2_test:
            best_p1 = p1
            best_p2 = p2
            best_r2_train = r2_train
            best_r2_test = r2_test
# Out:
# Processing hypothesis with p1 = 0 p2 =  0
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.866242568725562 0.8513115670851457
# Processing hypothesis with p1 = 0 p2 =  1
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8723451041747389 0.855593474046324
# Processing hypothesis with p1 = 0 p2 =  2
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8708280001031088 0.8552222922153929
# Processing hypothesis with p1 = 0 p2 =  3
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8657397822197052 0.849364852521982
# Processing hypothesis with p1 = 0 p2 =  4
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8583529057722534 0.840053296709843
# Processing hypothesis with p1 = 1 p2 =  0
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8670766779715617 0.8505047802149835
# Processing hypothesis with p1 = 1 p2 =  1
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8724664228815229 0.85596851933342
# Processing hypothesis with p1 = 1 p2 =  2
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8712750197247061 0.8544395025901375
# Processing hypothesis with p1 = 1 p2 =  3
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.865838057275627 0.8494743618574224
# Processing hypothesis with p1 = 1 p2 =  4
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8583961132962269 0.8402692040936452
# Processing hypothesis with p1 = 2 p2 =  0
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.867366731770469 0.8507840948951617
# Processing hypothesis with p1 = 2 p2 =  1
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8725060568638133 0.8561227144172188
# Processing hypothesis with p1 = 2 p2 =  2
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8712969393666331 0.854343701376646
# Processing hypothesis with p1 = 2 p2 =  3
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8660446914375435 0.8483566763815208
# Processing hypothesis with p1 = 2 p2 =  4
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.85838559433674 0.8403717831600594
# Processing hypothesis with p1 = 3 p2 =  0
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.867570209178265 0.8508487120989912
# Processing hypothesis with p1 = 3 p2 =  1
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8725351340766329 0.8573999160233257
# Processing hypothesis with p1 = 3 p2 =  2
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8712987587997268 0.8543506319101863
# Processing hypothesis with p1 = 3 p2 =  3
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8660635535113739 0.8487415331833891
# Processing hypothesis with p1 = 3 p2 =  4
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8582367170259158 0.8402639460170966
# Processing hypothesis with p1 = 4 p2 =  0
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.867354168654565 0.8521885501121057
# Processing hypothesis with p1 = 4 p2 =  1
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8725598513837849 0.8575330769879683
# Processing hypothesis with p1 = 4 p2 =  2
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8711541129415139 0.8556067991314551
# Processing hypothesis with p1 = 4 p2 =  3
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.865939261798443 0.8482838673853477
# Processing hypothesis with p1 = 4 p2 =  4
# Index(['CRIM', 'ZN', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT',
#        'RM*LSTAT', 'ONES'],
#       dtype='object')
# 0.8582205654964378 0.8402631404789412

# %%
print(
    "Optimize p for hypothesis: p1 =",
    best_p1,
    "p2 =",
    best_p2,
    "r2_train:",
    best_r2_train,
    "r2_test:",
    best_r2_test,
)
# Out:
# Optimize p for hypothesis: p1 = 4 p2 = 1 r2_train: 0.8725598513837849 r2_test: 0.8575330769879683
